# %%
from sqlalchemy import create_engine 
import pandas as pd

# %%
DATABASE_TYPE="postgresql"
USERNAME="mutakabbir"
PASSWORD="lightning"
HOST="localhost"
PORT=5432
DATABASE_NAME="postgres"

# %%
engine = create_engine(f"{DATABASE_TYPE}://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE_NAME}")

# %%
query_avg_division_dataset = """
select 
	record_date,
	avg(idd.extraterrestrial_irradiance) as extraterrestrial_irradiance,
	avg(idd.global_horizontal_irradiance) as global_horizontal_irradiance,
	avg(idd.direct_normal_irradience) as direct_normal_irradience,
	avg(idd.diffuse_horizontal_irradiance) as diffuse_horizontal_irradiance,
	avg(idd.global_horizontal_illumination_klux) as global_horizontal_illumination_klux,
	avg(idd.direct_normal_illumination_klux) as direct_normal_illumination_klux,
	avg(idd.diffuse_horizontal_illumination_klux) as diffuse_horizontal_illumination_klux,
	avg(idd.zenith_illumination) as zenith_illumination,
	avg(idd.sunlight_min) as sunlight_min,
	avg(idd.ceiling_height_meters) as ceiling_height_meters,
	avg(idd.sky_layer_1) as sky_layer_1,
	avg(idd.sky_layer_2) as sky_layer_2,
	avg(idd.sky_layer_3) as sky_layer_3,
	avg(idd.sky_layer_4) as sky_layer_4,
	avg(idd.visibility_km) as visibility_km,
	avg(idd.weather_thunderstorm) as weather_thunderstorm,
	avg(idd.weather_rain) as weather_rain,
	avg(idd.weather_drizzle) as weather_drizzle,
	avg(idd.weather_snow_1) as weather_snow_1,
	avg(idd.weather_snow_2) as weather_snow_2,
	avg(idd.weather_ice) as weather_ice,
	avg(idd.weather_visibility_1) as weather_visibility_1,
	avg(idd.weather_visibility_2) as weather_visibility_2,
	avg(idd.pressure_kpa) as pressure_kpa,
	avg(idd.dry_bulb_temp_c) as dry_bulb_temp_c,
	avg(idd.dew_point_temp_c) as dew_point_temp_c,
	avg(idd.wind_direction_deg) as wind_direction_deg,
	avg(idd.wind_speed_mps) as wind_speed_mps,
	avg(idd.sky_cover) as sky_cover,
	avg(idd.sky_cover_opaque) as sky_cover_opaque,
	avg(idd.snow) as snow 
from 
	ics_division_dataset idd 
group by 
	idd.record_date 
"""

# %%
dataset = pd.read_sql(query_avg_division_dataset, con=engine, index_col="record_date")
dataset
# Out:
#              extraterrestrial_irradiance  global_horizontal_irradiance  \
# record_date
# 1998-01-01                    464.297071                    162.331448
# 1998-01-02                    452.516585                    183.299672
# 1998-01-03                    458.087442                    167.151112
# 1998-01-04                    457.730482                    175.785110
# 1998-01-05                    460.362625                    140.388424
# ...                                  ...                           ...
# 2017-12-28                    501.406542                    203.627839
# 2017-12-29                    505.074029                    182.219138
# 2017-12-30                    506.731911                    199.305579
# 2017-12-31                    510.522579                    231.769307
# 2018-01-01                    120.739966                      0.079459
#
#              direct_normal_irradience  diffuse_horizontal_irradiance  \
# record_date
# 1998-01-01                 216.112378                     105.250051
# 1998-01-02                 308.497670                     105.622830
# 1998-01-03                 235.409424                     111.969184
# 1998-01-04                 295.183045                      98.291548
# 1998-01-05                 142.716338                     105.190093
# ...                               ...                            ...
# 2017-12-28                 528.448597                      65.383634
# 2017-12-29                 394.557969                      82.036189
# 2017-12-30                 463.325569                      83.123588
# 2017-12-31                 649.257808                      66.353523
# 2018-01-01                   0.262572                       0.047579
#
#              global_horizontal_illumination_klux  \
# record_date
# 1998-01-01                              5.041230
# 1998-01-02                              5.623992
# 1998-01-03                              5.182889
# 1998-01-04                              5.386836
# 1998-01-05                              4.398970
# ...                                          ...
# 2017-12-28                              5.956451
# 2017-12-29                              5.441148
# 2017-12-30                              5.910856
# 2017-12-31                              6.716045
# 2018-01-01                              0.000000
#
#              direct_normal_illumination_klux  \
# record_date
# 1998-01-01                          5.582150
# 1998-01-02                          7.790532
# 1998-01-03                          5.768521
# 1998-01-04                          7.571091
# 1998-01-05                          3.594646
# ...                                      ...
# 2017-12-28                         13.423845
# 2017-12-29                          9.888457
# 2017-12-30                         11.653571
# 2017-12-31                         16.377488
# 2018-01-01                          0.000000
#
#              diffuse_horizontal_illumination_klux  zenith_illumination  \
# record_date
# 1998-01-01                               3.495346                  0.0
# 1998-01-02                               3.558102                  0.0
# 1998-01-03                               3.741293                  0.0
# 1998-01-04                               3.288482                  0.0
# 1998-01-05                               3.467013                  0.0
# ...                                           ...                  ...
# 2017-12-28                               2.235896                  0.0
# 2017-12-29                               2.773784                  0.0
# 2017-12-30                               2.819333                  0.0
# 2017-12-31                               2.286675                  0.0
# 2018-01-01                               0.000000                  0.0
#
#              sunlight_min  ceiling_height_meters  ...  weather_visibility_1  \
# record_date                                       ...
# 1998-01-01       0.328409            4547.260116  ...              0.014093
# 1998-01-02       0.953141            4475.349868  ...              0.036471
# 1998-01-03       0.327745            3775.461413  ...              0.058441
# 1998-01-04       0.296531            4397.626399  ...              0.062181
# 1998-01-05       0.485403            3349.657737  ...              0.200087
# ...                   ...                    ...  ...                   ...
# 2017-12-28       0.000000             109.842095  ...              0.006255
# 2017-12-29       0.000000              94.473001  ...              0.030452
# 2017-12-30       0.000000              50.630257  ...              0.001823
# 2017-12-31       0.000000             124.904400  ...              0.008702
# 2018-01-01       0.000000             137.816199  ...              0.000000
#
#              weather_visibility_2  pressure_kpa  dry_bulb_temp_c  \
# record_date
# 1998-01-01               0.003064     98.149351       -11.477234
# 1998-01-02               0.001506     98.190563        -6.700070
# 1998-01-03               0.002425     98.143710        -3.370138
# 1998-01-04               0.003625     98.897745        -7.963659
# 1998-01-05               0.000000     98.841406        -6.954701
# ...                           ...           ...              ...
# 2017-12-28               0.154494     99.895064       -17.458115
# 2017-12-29               0.044869     99.453573       -16.389676
# 2017-12-30               0.134263     99.088798       -16.476116
# 2017-12-31               0.064214     99.667783       -18.574991
# 2018-01-01               0.048372     99.794069       -19.253921
#
#              dew_point_temp_c  wind_direction_deg  wind_speed_mps  sky_cover  \
# record_date
# 1998-01-01         -15.072816          177.859241        4.460371   8.120075
# 1998-01-02         -10.108775          171.720519        3.655687   8.136601
# 1998-01-03          -6.442330          189.237671        4.221126   8.478826
# 1998-01-04         -11.742905          127.802413        4.100899   8.027763
# 1998-01-05          -9.017404           94.253016        2.778575   8.657410
# ...                       ...                 ...             ...        ...
# 2017-12-28         -21.444861          205.956283        3.435141   5.867950
# 2017-12-29         -19.616223          188.923671        2.769837   7.101116
# 2017-12-30         -19.866065          199.452109        3.229356   6.211957
# 2017-12-31         -22.529184          228.880192        3.279178   3.235056
# 2018-01-01         -22.670649          224.478862        2.946908   5.005051
#
#              sky_cover_opaque      snow
# record_date
# 1998-01-01           7.545322  0.752294
# 1998-01-02           7.528174  0.722602
# 1998-01-03           7.764293  0.679625
# 1998-01-04           7.418175  0.678108
# 1998-01-05           8.151996  0.659484
# ...                       ...       ...
# 2017-12-28           7.402778  0.971985
# 2017-12-29           7.222222  0.964003
# 2017-12-30           7.048611  0.964899
# 2017-12-31           5.965278  0.958213
# 2018-01-01           4.666667  0.957920
#
# [7306 rows x 31 columns]

# %%
dataset.plot(
    figsize=(40,80),
    subplots=True
)
# Out:
# array([<AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>,
#        <AxesSubplot:xlabel='record_date'>], dtype=object)
