# %%
from sqlalchemy import create_engine 
import pandas as pd

# %%
DATABASE_TYPE="postgresql"
USERNAME="mutakabbir"
PASSWORD="lightning"
HOST="localhost"
PORT=5432
DATABASE_NAME="postgres"
DIVISION_ICS_DATASET_TABLE="ics_division_dataset"

# %%
engine = create_engine(f"{DATABASE_TYPE}://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE_NAME}")

# %%
query_drop_dataset_table = f"""DROP TABLE IF EXISTS {DIVISION_ICS_DATASET_TABLE};"""

query_add_pk_to_dataset_table = f"""ALTER TABLE {DIVISION_ICS_DATASET_TABLE} ADD PRIMARY KEY ("division_id", "record_date");"""

query_subdivision_list = f"""select distinct(ds."FEDUID") from division_station ds"""

query_stations_in_subdivision = lambda division_id: f"""select distinct(ds."climate_ID") from division_station ds where ds."FEDUID" = {division_id}"""

# %%
query_extract_subdivision_dataset = lambda division_id, station_list: f"""
select 
	{division_id} as division_id,
	date_trunc('hour', date_trunc('day', dd."Year Month Day Hour (YYYYMMDDHH)")) as "record_date",
	avg(dd."Extraterrestrial irradiance / kJ/m2") as "extraterrestrial_irradiance",
	avg(
		case 
			when dd."Flag" = '9' then 0
			else dd."Global horizontal irradiance / kJ/m2"
		end
	) as "global_horizontal_irradiance",
	avg(
		case 
			when dd."Flag.1" = '9' then 0
			else dd."Direct normal irradiance / kJ/m2"
		end
	) as "direct_normal_irradience",
	avg(
		case 
			when "Flag.2" = '9' then 0
			else dd."Diffuse horizontal irradiance / kJ/m2"
		end
	) as "diffuse_horizontal_irradiance",
	avg(
		case 
			when dd."Flag.3" = '9' then 0
			else dd."Global horizontal illuminance / 100 lux" 
		end
	) / 10 "global_horizontal_illumination_klux", -- calculate /kluxas 
	avg(
		case 
			when dd."Flag.4" = '9' then 0 
			else dd."Direct normal illuminance / 100 lux" 
		end
	) / 10 as "direct_normal_illumination_klux", -- calculate /klux
	avg(
		case 
			when dd."Flag.5" = '9' then 0 
			else dd."Diffuse horizontal illuminance / 100 lux"
		end
	) / 10 as "diffuse_horizontal_illumination_klux", -- calculate /klux
	avg(
		case 
			when dd."Flag.6" = '9' then 0 
			else dd."Zenith luminance / 100 Cd/m2"
		end
	) as "zenith_illumination",
	avg(
		case 
			when dd."Flag.7" = '9' then 0 
			else dd."Minutes of sunshine / 0-60 minutes"
		end
	) as "sunlight_min",
	avg(
		case 
			when dd."Flag.8" = '9' then 0 
			when dd."Ceiling height / 10 m" = 7777 then 3000 -- 7777 represents no limit. hence put max value of 3,000 
			else dd."Ceiling height / 10 m" 
		end
	) * 10 as "ceiling_height_meters", -- multiply wwith 10 since it is represented per 10 m
	avg(
		case 
			when dd."Flag.9" = '9' then 0
			else substring(lpad(dd."Sky condition"::text, 4, '0'), 1, 1)::integer  -- extract layer 1
		end
	) as "sky_layer_1",
	avg(
		case 
			when dd."Flag.9" = '9' then 0
			else substring(lpad(dd."Sky condition"::text, 4, '0'), 2, 1)::integer -- extract layer 2
		end
	) as "sky_layer_2",
	avg(
		case 
			when dd."Flag.9" = '9' then 0
			else substring(lpad(dd."Sky condition"::text, 4, '0'), 3, 1)::integer -- extract layer 3
		end
	) as "sky_layer_3",
	avg(
		case 
			when dd."Flag.9" = '9' then 0
			else substring(lpad(dd."Sky condition"::text, 4, '0'), 4, 1)::integer -- extract layer 4
		end
	) as "sky_layer_4",
	avg(
		case 
			when dd."Flag.10" = '9' then 0
			else dd."Visibility / 100 m" 
		end
	) / 10 as "visibility_km",  -- convert to visibility / 1 km
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 1, 1)::integer
		end
	) as "weather_thunderstorm",
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 2, 1)::integer
		end
	) as "weather_rain",
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 3, 1)::integer
		end
	) as "weather_drizzle",
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 4, 1)::integer
		end
	) as "weather_snow_1",
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 5, 1)::integer
		end
	) as "weather_snow_2",
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 6, 1)::integer
		end
	) as "weather_ice",
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 7, 1)::integer
		end
	) as "weather_visibility_1",
	avg(
		case 
			when dd."Flag.11" = '9' then 0
			else substring(lpad(dd."Present Weather"::text, 8, '0'), 8, 1)::integer
		end
	) as "weather_visibility_2",
	avg(
		case 
			when dd."Flag.12" = '9' then 0
			else dd."Station pressure / 10 Pa"  
		end
	) / 100 as "pressure_kpa", -- convert to presure / kPa
	avg(
		case 
			when dd."Flag.13" = '9' then null
			else dd."Dry bulb temperature / 0.1 C"
		end
	) / 10 as "dry_bulb_temp_c", -- convert to / 1 C
	avg(
		case 
			when dd."Flag.14" = '9' then null
			else dd."Dew point temperature / 0.1 C"
		end
	) / 10 as "dew_point_temp_c", -- convert to / 1 C
	avg(
		case 
			when dd."Flag.15" = '9' then null
			else dd."Wind direction / 0-359 degrees"
		end
	) as "wind_direction_deg",
	avg(
		case 
			when dd."Flag.16" = '9' then null
			else dd."Wind speed / 0.1 m/s"
		end
	)  / 10 as "wind_speed_mps",
	avg(
		case 
			when dd."Flag.17" = '9' then null
			else dd."Total sky cover / 0-10 in tenths"
		end
	) as "sky_cover",
	avg(
		case 
			when dd."Flag.18" = '9' then null
			else dd."Opaque sky cover / 0-10 in tenths"
		end
	) as "sky_cover_opaque",
	avg(
		case 
			when dd."Flag.19" = '9' then 0
			else dd."Snow cover (0 = no snow cover 1 = snow cover)"
		end
	) as "snow"
from (
	select * 
	from 
		ics 
	where 
		ics."ECCC station identifier" in ('{"','".join(station_list)}') 
) as dd
group by record_date
"""

# %%
# add all the data to db

# drop table data if it exists
with engine.connect() as con:
    con.execute(query_drop_dataset_table)
# get division list
division_list = pd.read_sql(query_subdivision_list, con=engine)["FEDUID"].values.tolist()

# add data for each division
for index, division_id in enumerate(division_list):
    print(f"Started subdivision ({index}): {division_id}")
    station_list = pd.read_sql(query_stations_in_subdivision(division_id), con=engine)["climate_ID"].values.tolist()
    print(f"\tstation list: {station_list}")
    division_dataset = pd.read_sql(
        query_extract_subdivision_dataset(
            division_id=division_id, 
            station_list=station_list
        ), 
        con=engine,
    )
    division_dataset.to_sql(name=DIVISION_ICS_DATASET_TABLE, con=engine, if_exists='append', index=False)
    del division_dataset
    print(f"\tfinished adding subdivision: {division_id}")
# add primary key for faster query
with engine.connect() as con:
    con.execute(query_add_pk_to_dataset_table)
# Out:
# Started subdivision (0): 47009
# 	station list: ['4016566']
# 	finished adding subdivision: 47009
# Started subdivision (1): 24005
# 	station list: ['7033121']
# 	finished adding subdivision: 24005
# Started subdivision (2): 35039
# 	station list: ['616I001']
# 	finished adding subdivision: 35039
# Started subdivision (3): 35103
# 	station list: ['605DJ25']
# 	finished adding subdivision: 35103
# Started subdivision (4): 24021
# 	station list: ['7027039']
# 	finished adding subdivision: 24021
# Started subdivision (5): 59027
# 	station list: ['1018621']
# 	finished adding subdivision: 59027
# Started subdivision (6): 48020
# 	station list: ['3012202']
# 	finished adding subdivision: 48020
# Started subdivision (7): 12007
# 	station list: ['8202810']
# 	finished adding subdivision: 12007
# Started subdivision (8): 35111
# 	station list: ['6158731']
# 	finished adding subdivision: 35111
# Started subdivision (9): 24050
# 	station list: ['7014160']
# 	finished adding subdivision: 24050
# Started subdivision (10): 24015
# 	station list: ['7025252']
# 	finished adding subdivision: 24015
# Started subdivision (11): 47004
# 	station list: ['4046884']
# 	finished adding subdivision: 47004
# Started subdivision (12): 24074
# 	station list: ['702FHL8']
# 	finished adding subdivision: 24074
# Started subdivision (13): 35016
# 	station list: ['6142286']
# 	finished adding subdivision: 35016
# Started subdivision (14): 59040
# 	station list: ['1108395']
# 	finished adding subdivision: 59040
# Started subdivision (15): 35090
# 	station list: ['6158355']
# 	finished adding subdivision: 35090
# Started subdivision (16): 35001
# 	station list: ['6158410']
# 	finished adding subdivision: 35001
# Started subdivision (17): 48005
# 	station list: ['3031092']
# 	finished adding subdivision: 48005
# Started subdivision (18): 35029
# 	station list: ['6158731']
# 	finished adding subdivision: 35029
# Started subdivision (19): 13002
# 	station list: ['8103201']
# 	finished adding subdivision: 13002
# Started subdivision (20): 24042
# 	station list: ['7016293']
# 	finished adding subdivision: 24042
# Started subdivision (21): 35011
# 	station list: ['6158731']
# 	finished adding subdivision: 35011
# Started subdivision (22): 35009
# 	station list: ['6158731']
# 	finished adding subdivision: 35009
# Started subdivision (23): 35096
# 	station list: ['6158410']
# 	finished adding subdivision: 35096
# Started subdivision (24): 35019
# 	station list: ['6158355']
# 	finished adding subdivision: 35019
# Started subdivision (25): 47002
# 	station list: ['4028038', '4032322', '4028060', '4020286', '4024714', '4036844', '402DAF0', '4043901', '4038412', '4024919', '4031999']
# 	finished adding subdivision: 47002
# Started subdivision (26): 46011
# 	station list: ['5023262']
# 	finished adding subdivision: 46011
# Started subdivision (27): 48007
# 	station list: ['3031875']
# 	finished adding subdivision: 48007
# Started subdivision (28): 24046
# 	station list: ['704C64L', '7040442', '7045401', '7047911', '704F0PN', '7046059', '7043019', '7056202', '7041382', '704S001', '7044328', '7117823', '7040815']
# 	finished adding subdivision: 24046
# Started subdivision (29): 35087
# 	station list: ['6158410']
# 	finished adding subdivision: 35087
# Started subdivision (30): 59013
# 	station list: ['1160H99', '1161661', '1163781']
# 	finished adding subdivision: 59013
# Started subdivision (31): 48016
# 	station list: ['3014921']
# 	finished adding subdivision: 48016
# Started subdivision (32): 35063
# 	station list: ['6158731']
# 	finished adding subdivision: 35063
# Started subdivision (33): 35098
# 	station list: ['6158355']
# 	finished adding subdivision: 35098
# Started subdivision (34): 35010
# 	station list: ['6158731']
# 	finished adding subdivision: 35010
# Started subdivision (35): 24044
# 	station list: ['7016293', '701Q004']
# 	finished adding subdivision: 24044
# Started subdivision (36): 24031
# 	station list: ['703GDKB']
# 	finished adding subdivision: 24031
# Started subdivision (37): 46004
# 	station list: ['5010547', '5012469', '5012654', '5013117', '5040689', '5043158', '504K80K']
# 	finished adding subdivision: 46004
# Started subdivision (38): 59028
# 	station list: ['1066482', '1051351', '1077499', '1057052', '1056869', '1091174', '1068134', '119BLM0']
# 	finished adding subdivision: 59028
# Started subdivision (39): 47006
# 	station list: ['4055079', '4056241', '407N51G']
# 	finished adding subdivision: 47006
# Started subdivision (40): 35018
# 	station list: ['6158355']
# 	finished adding subdivision: 35018
# Started subdivision (41): 35075
# 	station list: ['6106001']
# 	finished adding subdivision: 35075
# Started subdivision (42): 24008
# 	station list: ['7010565']
# 	finished adding subdivision: 24008
# Started subdivision (43): 47005
# 	station list: ['4014156', '4015322', '4018642', '4022359', '4055736']
# 	finished adding subdivision: 47005
# Started subdivision (44): 10002
# 	station list: ['8400601', '8403619', '8403851', '8404241']
# 	finished adding subdivision: 10002
# Started subdivision (45): 35021
# 	station list: ['6158355']
# 	finished adding subdivision: 35021
# Started subdivision (46): 35105
# 	station list: ['6020LPQ', '6048262', '6049095']
# 	finished adding subdivision: 35105
# Started subdivision (47): 59016
# 	station list: ['1106178']
# 	finished adding subdivision: 59016
# Started subdivision (48): 46009
# 	station list: ['5023262']
# 	finished adding subdivision: 46009
# Started subdivision (49): 59039
# 	station list: ['1108395']
# 	finished adding subdivision: 59039
# Started subdivision (50): 48017
# 	station list: ['3012202']
# 	finished adding subdivision: 48017
# Started subdivision (51): 35002
# 	station list: ['6059413', '6073976', '6075543', '6092920']
# 	finished adding subdivision: 35002
# Started subdivision (52): 35095
# 	station list: ['6158410']
# 	finished adding subdivision: 35095
# Started subdivision (53): 24072
# 	station list: ['7022579']
# 	finished adding subdivision: 24072
# Started subdivision (54): 24026
# 	station list: ['7051050', '7052601', '7053KGR', '7055422']
# 	finished adding subdivision: 24026
# Started subdivision (55): 35017
# 	station list: ['613P001']
# 	finished adding subdivision: 35017
# Started subdivision (56): 24048
# 	station list: ['7034900']
# 	finished adding subdivision: 24048
# Started subdivision (57): 24051
# 	station list: ['7054096', '7056616']
# 	finished adding subdivision: 24051
# Started subdivision (58): 35028
# 	station list: ['6158731']
# 	finished adding subdivision: 35028
# Started subdivision (59): 24059
# 	station list: ['701Q004']
# 	finished adding subdivision: 24059
# Started subdivision (60): 48010
# 	station list: ['3031875']
# 	finished adding subdivision: 48010
# Started subdivision (61): 13010
# 	station list: ['810I001']
# 	finished adding subdivision: 13010
# Started subdivision (62): 59018
# 	station list: ['1020590']
# 	finished adding subdivision: 59018
# Started subdivision (63): 35080
# 	station list: ['6131983']
# 	finished adding subdivision: 35080
# Started subdivision (64): 24060
# 	station list: ['7014160']
# 	finished adding subdivision: 24060
# Started subdivision (65): 12004
# 	station list: ['8200573', '8205092']
# 	finished adding subdivision: 12004
# Started subdivision (66): 12011
# 	station list: ['8202000', '8206495']
# 	finished adding subdivision: 12011
# Started subdivision (67): 35117
# 	station list: ['6139527']
# 	finished adding subdivision: 35117
# Started subdivision (68): 13003
# 	station list: ['8101505']
# 	finished adding subdivision: 13003
# Started subdivision (69): 24004
# 	station list: ['7025252']
# 	finished adding subdivision: 24004
# Started subdivision (70): 46005
# 	station list: ['5023262']
# 	finished adding subdivision: 46005
# Started subdivision (71): 35074
# 	station list: ['6158410']
# 	finished adding subdivision: 35074
# Started subdivision (72): 35050
# 	station list: ['6104027']
# 	finished adding subdivision: 35050
# Started subdivision (73): 24028
# 	station list: ['7025252']
# 	finished adding subdivision: 24028
# Started subdivision (74): 24034
# 	station list: ['7024745']
# 	finished adding subdivision: 24034
# Started subdivision (75): 10001
# 	station list: ['8401000']
# 	finished adding subdivision: 10001
# Started subdivision (76): 46001
# 	station list: ['5010481', '501A7AR', '5022125']
# 	finished adding subdivision: 46001
# Started subdivision (77): 59031
# 	station list: ['1108395']
# 	finished adding subdivision: 59031
# Started subdivision (78): 35003
# 	station list: ['6158410']
# 	finished adding subdivision: 35003
# Started subdivision (79): 35052
# 	station list: ['6144473']
# 	finished adding subdivision: 35052
# Started subdivision (80): 10007
# 	station list: ['8403505']
# 	finished adding subdivision: 10007
# Started subdivision (81): 35045
# 	station list: ['6142286']
# 	finished adding subdivision: 35045
# Started subdivision (82): 59024
# 	station list: ['1096439', '1182289', '1183001', '1184791', '1192946']
# 	finished adding subdivision: 59024
# Started subdivision (83): 35058
# 	station list: ['6158731']
# 	finished adding subdivision: 35058
# Started subdivision (84): 47012
# 	station list: ['4057152']
# 	finished adding subdivision: 47012
# Started subdivision (85): 24052
# 	station list: ['7024745']
# 	finished adding subdivision: 24052
# Started subdivision (86): 47013
# 	station list: ['4010879', '4012401', '401HP5R', '40318MN']
# 	finished adding subdivision: 47013
# Started subdivision (87): 59033
# 	station list: ['1108910']
# 	finished adding subdivision: 59033
# Started subdivision (88): 24056
# 	station list: ['702FHL8']
# 	finished adding subdivision: 24056
# Started subdivision (89): 24027
# 	station list: ['6106001']
# 	finished adding subdivision: 24027
# Started subdivision (90): 59010
# 	station list: ['1014820']
# 	finished adding subdivision: 59010
# Started subdivision (91): 35077
# 	station list: ['6106001']
# 	finished adding subdivision: 35077
# Started subdivision (92): 60001
# 	station list: ['2100701', '2100518', '2100935', '2101201', '2100805', '2100693', '2100181', '2100LRP', '2101303', '2101102', '2100660', '2100301', '2100630']
# 	finished adding subdivision: 60001
# Started subdivision (93): 59041
# 	station list: ['1018598', '1018611']
# 	finished adding subdivision: 59041
# Started subdivision (94): 48026
# 	station list: ['3033498', '3033890', '3033897']
# 	finished adding subdivision: 48026
# Started subdivision (95): 47003
# 	station list: ['4060983', '4064155', '4063757', '406QLD0', '4067799', '4067723', '4067655', '4063605', '406N0NM', '4063623', '4068559', '4061620']
# 	finished adding subdivision: 47003
# Started subdivision (96): 35033
# 	station list: ['6131983']
# 	finished adding subdivision: 35033
# Started subdivision (97): 46002
# 	station list: ['5023227']
# 	finished adding subdivision: 46002
# Started subdivision (98): 35083
# 	station list: ['6145504']
# 	finished adding subdivision: 35083
# Started subdivision (99): 48011
# 	station list: ['3031092']
# 	finished adding subdivision: 48011
# Started subdivision (100): 35059
# 	station list: ['6158731']
# 	finished adding subdivision: 35059
# Started subdivision (101): 13008
# 	station list: ['8101925', '8104935']
# 	finished adding subdivision: 13008
# Started subdivision (102): 24041
# 	station list: ['7027329']
# 	finished adding subdivision: 24041
# Started subdivision (103): 59012
# 	station list: ['1106178']
# 	finished adding subdivision: 59012
# Started subdivision (104): 35041
# 	station list: ['6106001']
# 	finished adding subdivision: 35041
# Started subdivision (105): 24033
# 	station list: ['7025252']
# 	finished adding subdivision: 24033
# Started subdivision (106): 48025
# 	station list: ['3015676', '3010010', '3014665', '3010237', '3016GF0', '3016022', '3060406', '3012275', '3016655', '3013959', '3016802']
# 	finished adding subdivision: 48025
# Started subdivision (107): 48033
# 	station list: ['301A001']
# 	finished adding subdivision: 48033
# Started subdivision (108): 59020
# 	station list: ['1128582', '116FRMN']
# 	finished adding subdivision: 59020
# Started subdivision (109): 24062
# 	station list: ['7034900']
# 	finished adding subdivision: 24062
# Started subdivision (110): 35020
# 	station list: ['6158410']
# 	finished adding subdivision: 35020
# Started subdivision (111): 13006
# 	station list: ['8100989']
# 	finished adding subdivision: 13006
# Started subdivision (112): 24006
# 	station list: ['7050145', '7055121']
# 	finished adding subdivision: 24006
# Started subdivision (113): 59034
# 	station list: ['1108824']
# 	finished adding subdivision: 59034
# Started subdivision (114): 35047
# 	station list: ['6142286']
# 	finished adding subdivision: 35047
# Started subdivision (115): 13001
# 	station list: ['8100467', '8100505']
# 	finished adding subdivision: 13001
# Started subdivision (116): 24071
# 	station list: ['702FQLF']
# 	finished adding subdivision: 24071
# Started subdivision (117): 35049
# 	station list: ['6104027']
# 	finished adding subdivision: 35049
# Started subdivision (118): 24058
# 	station list: ['7011983']
# 	finished adding subdivision: 24058
# Started subdivision (119): 24001
# 	station list: ['7091299', '7094636', '7098603', '7103537', '710S005', '7113535']
# 	finished adding subdivision: 24001
# Started subdivision (120): 24057
# 	station list: ['7034482']
# 	finished adding subdivision: 24057
# Started subdivision (121): 48012
# 	station list: ['3031875']
# 	finished adding subdivision: 48012
# Started subdivision (122): 59032
# 	station list: ['1106178']
# 	finished adding subdivision: 59032
# Started subdivision (123): 35024
# 	station list: ['6158355']
# 	finished adding subdivision: 35024
# Started subdivision (124): 12002
# 	station list: ['8202251', '8203405']
# 	finished adding subdivision: 12002
# Started subdivision (125): 59025
# 	station list: ['1108395']
# 	finished adding subdivision: 59025
# Started subdivision (126): 24076
# 	station list: ['7025442']
# 	finished adding subdivision: 24076
# Started subdivision (127): 47014
# 	station list: ['4019075', '4083324']
# 	finished adding subdivision: 47014
# Started subdivision (128): 35116
# 	station list: ['6139527']
# 	finished adding subdivision: 35116
# Started subdivision (129): 24013
# 	station list: ['7034900']
# 	finished adding subdivision: 24013
# Started subdivision (130): 35012
# 	station list: ['6158731']
# 	finished adding subdivision: 35012
# Started subdivision (131): 48003
# 	station list: ['3023402', '3032422', '3036205', '3032550', '3036682', '3031480', '3030525', '3030QLP']
# 	finished adding subdivision: 48003
# Started subdivision (132): 35085
# 	station list: ['6158410']
# 	finished adding subdivision: 35085
# Started subdivision (133): 59017
# 	station list: ['1100119', '1114619', '1114746']
# 	finished adding subdivision: 59017
# Started subdivision (134): 46010
# 	station list: ['50309J6', '5031041', '5031042', '5032951', '503B1ER', '504K0NM']
# 	finished adding subdivision: 46010
# Started subdivision (135): 11001
# 	station list: ['8300418', '8300562']
# 	finished adding subdivision: 11001
# Started subdivision (136): 10006
# 	station list: ['8403505']
# 	finished adding subdivision: 10006
# Started subdivision (137): 59019
# 	station list: ['1106178']
# 	finished adding subdivision: 59019
# Started subdivision (138): 35094
# 	station list: ['6158410']
# 	finished adding subdivision: 35094
# Started subdivision (139): 35053
# 	station list: ['6144473']
# 	finished adding subdivision: 35053
# Started subdivision (140): 46003
# 	station list: ['5061422', '5052881', '5061645', '5062921', '5031A10', '5061022', '5061375', '5030984', '5050919', '5060605', '5062840', '5062040', '5030203']
# 	finished adding subdivision: 46003
# Started subdivision (141): 59026
# 	station list: ['1017254', '1018FJ5']
# 	finished adding subdivision: 59026
# Started subdivision (142): 35100
# 	station list: ['6114295']
# 	finished adding subdivision: 35100
# Started subdivision (143): 12001
# 	station list: ['8204154', '8205701', '8205895']
# 	finished adding subdivision: 12001
# Started subdivision (144): 47011
# 	station list: ['4057152']
# 	finished adding subdivision: 47011
# Started subdivision (145): 24018
# 	station list: ['8101303']
# 	finished adding subdivision: 24018
# Started subdivision (146): 35014
# 	station list: ['6119499']
# 	finished adding subdivision: 35014
# Started subdivision (147): 59015
# 	station list: ['1145M29', '114B1F0', '1152105', '1157631', '1176745', '11790J1']
# 	finished adding subdivision: 59015
# Started subdivision (148): 48023
# 	station list: ['3062697', '3063686', '3064528', '3065475', '3072655', '3081680']
# 	finished adding subdivision: 48023
# Started subdivision (149): 59021
# 	station list: ['1108824']
# 	finished adding subdivision: 59021
# Started subdivision (150): 35078
# 	station list: ['6106001']
# 	finished adding subdivision: 35078
# Started subdivision (151): 35043
# 	station list: ['6158410']
# 	finished adding subdivision: 35043
# Started subdivision (152): 35025
# 	station list: ['6144473']
# 	finished adding subdivision: 35025
# Started subdivision (153): 24077
# 	station list: ['7024745']
# 	finished adding subdivision: 24077
# Started subdivision (154): 24061
# 	station list: ['701Q009']
# 	finished adding subdivision: 24061
# Started subdivision (155): 59023
# 	station list: ['1106178']
# 	finished adding subdivision: 59023
# Started subdivision (156): 35015
# 	station list: ['6151061']
# 	finished adding subdivision: 35015
# Started subdivision (157): 12009
# 	station list: ['8202592']
# 	finished adding subdivision: 12009
# Started subdivision (158): 46014
# 	station list: ['5023262']
# 	finished adding subdivision: 46014
# Started subdivision (159): 59009
# 	station list: ['1020590']
# 	finished adding subdivision: 59009
# Started subdivision (160): 24073
# 	station list: ['7024280']
# 	finished adding subdivision: 24073
# Started subdivision (161): 10005
# 	station list: ['8401502', '8403097', '8402975', '8403801', '8400801', '8401298', '8404343', '8401400']
# 	finished adding subdivision: 10005
# Started subdivision (162): 12006
# 	station list: ['8200574']
# 	finished adding subdivision: 12006
# Started subdivision (163): 35035
# 	station list: ['6151061']
# 	finished adding subdivision: 35035
# Started subdivision (164): 35099
# 	station list: ['6111792', '611B002', '611E001']
# 	finished adding subdivision: 35099
# Started subdivision (165): 35107
# 	station list: ['6016295', '6072223', '6074211', '6075420', '6078286']
# 	finished adding subdivision: 35107
# Started subdivision (166): 24023
# 	station list: ['7024280']
# 	finished adding subdivision: 24023
# Started subdivision (167): 48030
# 	station list: ['3023722', '3025297']
# 	finished adding subdivision: 48030
# Started subdivision (168): 59036
# 	station list: ['1108395']
# 	finished adding subdivision: 59036
# Started subdivision (169): 24045
# 	station list: ['7016293']
# 	finished adding subdivision: 24045
# Started subdivision (170): 10004
# 	station list: ['8501101', '8501131', '8501900', '8502592', '8504177']
# 	finished adding subdivision: 10004
# Started subdivision (171): 48024
# 	station list: ['3070600', '3072921', '3073140', '3074190', '3074935', '3076069']
# 	finished adding subdivision: 48024
# Started subdivision (172): 35030
# 	station list: ['6153193', '6153301']
# 	finished adding subdivision: 35030
# Started subdivision (173): 35114
# 	station list: ['6158410']
# 	finished adding subdivision: 35114
# Started subdivision (174): 35072
# 	station list: ['6151061']
# 	finished adding subdivision: 35072
# Started subdivision (175): 24078
# 	station list: ['7025251']
# 	finished adding subdivision: 24078
# Started subdivision (176): 48014
# 	station list: ['3012202']
# 	finished adding subdivision: 48014
# Started subdivision (177): 35109
# 	station list: ['6158355']
# 	finished adding subdivision: 35109
# Started subdivision (178): 35037
# 	station list: ['6153193']
# 	finished adding subdivision: 35037
# Started subdivision (179): 24070
# 	station list: ['7018001', '7075800', '707DBD4']
# 	finished adding subdivision: 24070
# Started subdivision (180): 59014
# 	station list: ['1123939']
# 	finished adding subdivision: 59014
# Started subdivision (181): 47007
# 	station list: ['4016566']
# 	finished adding subdivision: 47007
# Started subdivision (182): 59037
# 	station list: ['1021830', '1022795', '1026271', '1037553']
# 	finished adding subdivision: 59037
# Started subdivision (183): 35026
# 	station list: ['6133362']
# 	finished adding subdivision: 35026
# Started subdivision (184): 35076
# 	station list: ['6106001']
# 	finished adding subdivision: 35076
# Started subdivision (185): 24029
# 	station list: ['7025252']
# 	finished adding subdivision: 24029
# Started subdivision (186): 35110
# 	station list: ['6158355']
# 	finished adding subdivision: 35110
# Started subdivision (187): 24020
# 	station list: ['7015791', '7041312', '7041JG6', '7042395']
# 	finished adding subdivision: 24020
# Started subdivision (188): 24040
# 	station list: ['7025251']
# 	finished adding subdivision: 24040
# Started subdivision (189): 13007
# 	station list: ['8103201']
# 	finished adding subdivision: 13007
# Started subdivision (190): 35081
# 	station list: ['6158355']
# 	finished adding subdivision: 35081
# Started subdivision (191): 35048
# 	station list: ['613KLLM']
# 	finished adding subdivision: 35048
# Started subdivision (192): 59001
# 	station list: ['1100031']
# 	finished adding subdivision: 59001
# Started subdivision (193): 24053
# 	station list: ['7024745']
# 	finished adding subdivision: 24053
# Started subdivision (194): 35092
# 	station list: ['6057591']
# 	finished adding subdivision: 35092
# Started subdivision (195): 35044
# 	station list: ['6156559']
# 	finished adding subdivision: 35044
# Started subdivision (196): 35093
# 	station list: ['6158410']
# 	finished adding subdivision: 35093
# Started subdivision (197): 24067
# 	station list: ['702LED4']
# 	finished adding subdivision: 24067
# Started subdivision (198): 35038
# 	station list: ['6153193']
# 	finished adding subdivision: 35038
# Started subdivision (199): 35062
# 	station list: ['6158731']
# 	finished adding subdivision: 35062
# Started subdivision (200): 35036
# 	station list: ['6151061']
# 	finished adding subdivision: 35036
# Started subdivision (201): 46007
# 	station list: ['5012324', '5020725', '5021220', '5021849', '502I001', '5040764']
# 	finished adding subdivision: 46007
# Started subdivision (202): 47010
# 	station list: ['4057152']
# 	finished adding subdivision: 47010
# Started subdivision (203): 12010
# 	station list: ['8200827', '8202502', '8204161']
# 	finished adding subdivision: 12010
# Started subdivision (204): 59008
# 	station list: ['1106178']
# 	finished adding subdivision: 59008
# Started subdivision (205): 48006
# 	station list: ['3031092']
# 	finished adding subdivision: 48006
# Started subdivision (206): 35108
# 	station list: ['6158355']
# 	finished adding subdivision: 35108
# Started subdivision (207): 35064
# 	station list: ['6106001']
# 	finished adding subdivision: 35064
# Started subdivision (208): 48004
# 	station list: ['3031092']
# 	finished adding subdivision: 48004
# Started subdivision (209): 35120
# 	station list: ['6158355']
# 	finished adding subdivision: 35120
# Started subdivision (210): 24037
# 	station list: ['7024745']
# 	finished adding subdivision: 24037
# Started subdivision (211): 35057
# 	station list: ['6153301']
# 	finished adding subdivision: 35057
# Started subdivision (212): 12008
# 	station list: ['8200574']
# 	finished adding subdivision: 12008
# Started subdivision (213): 13009
# 	station list: ['8104901']
# 	finished adding subdivision: 13009
# Started subdivision (214): 35006
# 	station list: ['6158875']
# 	finished adding subdivision: 35006
# Started subdivision (215): 11003
# 	station list: ['8300596']
# 	finished adding subdivision: 11003
# Started subdivision (216): 61001
# 	station list: ['2201450', '220L002', '2202201', '220B6Q3', '2202401', '2201799', '2202560', '220N005', '2202103', '2201579', '2201903', '2202663', '220N004', '220B68C', '220N003', '2201022', '2503886', '250M001', '2202801', '220LQJJ', '2202571', '2203342', '22010H0', '2202678', '2204300', '2503648', '2203095', '2203058', '2502505', '2203914', '2204101']
# 	finished adding subdivision: 61001
# Started subdivision (217): 46012
# 	station list: ['5023227']
# 	finished adding subdivision: 46012
# Started subdivision (218): 35104
# 	station list: ['6158410']
# 	finished adding subdivision: 35104
# Started subdivision (219): 35073
# 	station list: ['6151061']
# 	finished adding subdivision: 35073
# Started subdivision (220): 35070
# 	station list: ['6085680', '7080468']
# 	finished adding subdivision: 35070
# Started subdivision (221): 59035
# 	station list: ['1108395']
# 	finished adding subdivision: 59035
# Started subdivision (222): 24049
# 	station list: ['7027329']
# 	finished adding subdivision: 24049
# Started subdivision (223): 24030
# 	station list: ['6106001']
# 	finished adding subdivision: 24030
# Started subdivision (224): 24016
# 	station list: ['7022579', '702CFGG']
# 	finished adding subdivision: 24016
# Started subdivision (225): 35034
# 	station list: ['6166415']
# 	finished adding subdivision: 35034
# Started subdivision (226): 46008
# 	station list: ['5020881', '5022759']
# 	finished adding subdivision: 46008
# Started subdivision (227): 24032
# 	station list: ['704607C', '706I155', '7041166', '7060826', '7061541', '706I001', '7063370', '7064181']
# 	finished adding subdivision: 24032
# Started subdivision (228): 24068
# 	station list: ['7025251']
# 	finished adding subdivision: 24068
# Started subdivision (229): 35097
# 	station list: ['6158410']
# 	finished adding subdivision: 35097
# Started subdivision (230): 24022
# 	station list: ['7060400', '706Q001']
# 	finished adding subdivision: 24022
# Started subdivision (231): 48002
# 	station list: ['301S001', '3011240', '3010730', '3024965', '301B460', '30221LG', '3024668', '3016124', '3025243', '3026479', '3013340', '3011815', '3013640', '3011887']
# 	finished adding subdivision: 48002
# Started subdivision (232): 35084
# 	station list: ['6166415']
# 	finished adding subdivision: 35084
# Started subdivision (233): 59004
# 	station list: ['1086558', '1088015', '1096629', '1098941']
# 	finished adding subdivision: 59004
# Started subdivision (234): 35065
# 	station list: ['6158410']
# 	finished adding subdivision: 35065
# Started subdivision (235): 35060
# 	station list: ['6158731']
# 	finished adding subdivision: 35060
# Started subdivision (236): 35031
# 	station list: ['702FQLF']
# 	finished adding subdivision: 35031
# Started subdivision (237): 48034
# 	station list: ['3054843', '3016860', '3053536', '306GE70', '3063135', '3062246', '3010816', '3015523']
# 	finished adding subdivision: 48034
# Started subdivision (238): 35004
# 	station list: ['611E001']
# 	finished adding subdivision: 35004
# Started subdivision (239): 24069
# 	station list: ['7025252']
# 	finished adding subdivision: 24069
# Started subdivision (240): 48029
# 	station list: ['3024925', '3025481', '3026KNQ']
# 	finished adding subdivision: 48029
# Started subdivision (241): 24002
# 	station list: ['7086716', '7086719']
# 	finished adding subdivision: 24002
# Started subdivision (242): 35054
# 	station list: ['6158410']
# 	finished adding subdivision: 35054
# Started subdivision (243): 24019
# 	station list: ['7016293']
# 	finished adding subdivision: 24019
# Started subdivision (244): 35051
# 	station list: ['6144473']
# 	finished adding subdivision: 35051
# Started subdivision (245): 35068
# 	station list: ['6139148']
# 	finished adding subdivision: 35068
# Started subdivision (246): 35032
# 	station list: ['6142286']
# 	finished adding subdivision: 35032
# Started subdivision (247): 35089
# 	station list: ['6136699']
# 	finished adding subdivision: 35089
# Started subdivision (248): 24038
# 	station list: ['703GDKB']
# 	finished adding subdivision: 24038
# Started subdivision (249): 24007
# 	station list: ['7028754']
# 	finished adding subdivision: 24007
# Started subdivision (250): 35102
# 	station list: ['6104027']
# 	finished adding subdivision: 35102
# Started subdivision (251): 24010
# 	station list: ['7028754']
# 	finished adding subdivision: 24010
# Started subdivision (252): 59022
# 	station list: ['1106178']
# 	finished adding subdivision: 59022
# Started subdivision (253): 59029
# 	station list: ['1125852', '1126146', '112G8L1', '1145297', '1148705']
# 	finished adding subdivision: 59029
# Started subdivision (254): 13004
# 	station list: ['8104901']
# 	finished adding subdivision: 13004
# Started subdivision (255): 48013
# 	station list: ['3031092']
# 	finished adding subdivision: 48013
# Started subdivision (256): 12003
# 	station list: ['8201390', '8203702', '8204402']
# 	finished adding subdivision: 12003
# Started subdivision (257): 35027
# 	station list: ['6158731']
# 	finished adding subdivision: 35027
# Started subdivision (258): 24054
# 	station list: ['7024745']
# 	finished adding subdivision: 24054
# Started subdivision (259): 35066
# 	station list: ['6136699']
# 	finished adding subdivision: 35066
# Started subdivision (260): 12005
# 	station list: ['8205092']
# 	finished adding subdivision: 12005
# Started subdivision (261): 59038
# 	station list: ['1108395']
# 	finished adding subdivision: 59038
# Started subdivision (262): 35106
# 	station list: ['6040325', '6041110', '6042717', '6046768']
# 	finished adding subdivision: 35106
# Started subdivision (263): 35113
# 	station list: ['6142286']
# 	finished adding subdivision: 35113
# Started subdivision (264): 24014
# 	station list: ['702327X']
# 	finished adding subdivision: 24014
# Started subdivision (265): 35008
# 	station list: ['6158731']
# 	finished adding subdivision: 35008
# Started subdivision (266): 48028
# 	station list: ['3061975', '3076680', '3075160', '3072723', '3060535', '3065995', '307KPFP', '3075488', '3057376', '3075041', '3063165', '3072525']
# 	finished adding subdivision: 48028
# Started subdivision (267): 59011
# 	station list: ['1108395']
# 	finished adding subdivision: 59011
# Started subdivision (268): 24009
# 	station list: ['701Q009', '7025442']
# 	finished adding subdivision: 24009
# Started subdivision (269): 24063
# 	station list: ['7034900']
# 	finished adding subdivision: 24063
# Started subdivision (270): 35071
# 	station list: ['6151684']
# 	finished adding subdivision: 35071
# Started subdivision (271): 35067
# 	station list: ['6136699']
# 	finished adding subdivision: 35067
# Started subdivision (272): 35119
# 	station list: ['6117700']
# 	finished adding subdivision: 35119
# Started subdivision (273): 35022
# 	station list: ['611B002']
# 	finished adding subdivision: 35022
# Started subdivision (274): 24017
# 	station list: ['7027329']
# 	finished adding subdivision: 24017
# Started subdivision (275): 35040
# 	station list: ['6122847']
# 	finished adding subdivision: 35040
# Started subdivision (276): 35082
# 	station list: ['6115529']
# 	finished adding subdivision: 35082
# Started subdivision (277): 24003
# 	station list: ['7025251']
# 	finished adding subdivision: 24003
# Started subdivision (278): 48015
# 	station list: ['3012202']
# 	finished adding subdivision: 48015
# Started subdivision (279): 48008
# 	station list: ['3031092']
# 	finished adding subdivision: 48008
# Started subdivision (280): 24066
# 	station list: ['701LP0N']
# 	finished adding subdivision: 24066
# Started subdivision (281): 59030
# 	station list: ['1108910']
# 	finished adding subdivision: 59030
# Started subdivision (282): 59005
# 	station list: ['112FN0M']
# 	finished adding subdivision: 59005
# Started subdivision (283): 48001
# 	station list: ['3050519', '3050778']
# 	finished adding subdivision: 48001
# Started subdivision (284): 46006
# 	station list: ['5023262']
# 	finished adding subdivision: 46006
# Started subdivision (285): 24047
# 	station list: ['7028754']
# 	finished adding subdivision: 24047
# Started subdivision (286): 35079
# 	station list: ['6106001']
# 	finished adding subdivision: 35079
# Started subdivision (287): 35121
# 	station list: ['6158731']
# 	finished adding subdivision: 35121
# Started subdivision (288): 35013
# 	station list: ['6153193']
# 	finished adding subdivision: 35013
# Started subdivision (289): 11004
# 	station list: ['8305500', '830P001']
# 	finished adding subdivision: 11004
# Started subdivision (290): 35005
# 	station list: ['6117700']
# 	finished adding subdivision: 35005
# Started subdivision (291): 35091
# 	station list: ['613KLLM']
# 	finished adding subdivision: 35091
# Started subdivision (292): 24065
# 	station list: ['7025251']
# 	finished adding subdivision: 24065
# Started subdivision (293): 48032
# 	station list: ['3012275']
# 	finished adding subdivision: 48032
# Started subdivision (294): 10003
# 	station list: ['8400301', '8401703', '8402520', '8403255', '8404025']
# 	finished adding subdivision: 10003
# Started subdivision (295): 24043
# 	station list: ['7027329']
# 	finished adding subdivision: 24043
# Started subdivision (296): 59006
# 	station list: ['1113542']
# 	finished adding subdivision: 59006
# Started subdivision (297): 35112
# 	station list: ['6142286']
# 	finished adding subdivision: 35112
# Started subdivision (298): 48018
# 	station list: ['3012202']
# 	finished adding subdivision: 48018
# Started subdivision (299): 59003
# 	station list: ['1108395']
# 	finished adding subdivision: 59003
# Started subdivision (300): 46013
# 	station list: ['5023262']
# 	finished adding subdivision: 46013
# Started subdivision (301): 35007
# 	station list: ['6158355']
# 	finished adding subdivision: 35007
# Started subdivision (302): 48031
# 	station list: ['3012202']
# 	finished adding subdivision: 48031
# Started subdivision (303): 35069
# 	station list: ['6068153']
# 	finished adding subdivision: 35069
# Started subdivision (304): 59002
# 	station list: ['1108824']
# 	finished adding subdivision: 59002
# Started subdivision (305): 48027
# 	station list: ['3030768', '3031322', '3034485', '3037675', '3044533', '3044923', '3035845', '3025768', '3030772', '3035422', '3044232', '3042045', '3032642', '3030720']
# 	finished adding subdivision: 48027
# Started subdivision (306): 24064
# 	station list: ['7024745']
# 	finished adding subdivision: 24064
# Started subdivision (307): 11002
# 	station list: ['8300301']
# 	finished adding subdivision: 11002
# Started subdivision (308): 35118
# 	station list: ['6158355']
# 	finished adding subdivision: 35118
# Started subdivision (309): 24039
# 	station list: ['7024745']
# 	finished adding subdivision: 24039
# Started subdivision (310): 13005
# 	station list: ['8100885', '8101303', '810I001']
# 	finished adding subdivision: 13005
# Started subdivision (311): 47001
# 	station list: ['4045695', '4047240']
# 	finished adding subdivision: 47001
# Started subdivision (312): 62001
# 	station list: ['2403450', '2403625', '2300903', '2400305', '2400802', '2401203', '2302370', '2402596', '2403498', '2301002', '2400601', '2400650', '2300503', '2400660', '2301153', '2303685', '2303405', '2400565', '2402604', '2402354', '2403855', '2303094', '2403206', '230N002', '2400F63', '2301102', '2402351', '2403602', '2402684', '2400404', '2302340', '2401030', '2400570', '2400636', '2400697']
# 	finished adding subdivision: 62001
# Started subdivision (313): 59007
# 	station list: ['1106178']
# 	finished adding subdivision: 59007
# Started subdivision (314): 35115
# 	station list: ['6158410']
# 	finished adding subdivision: 35115
# Started subdivision (315): 59042
# 	station list: ['10476F0', '1086082', '1100875', '1101300', '1108824']
# 	finished adding subdivision: 59042
# Started subdivision (316): 35061
# 	station list: ['6158731']
# 	finished adding subdivision: 35061
# Started subdivision (317): 35101
# 	station list: ['6158359']
# 	finished adding subdivision: 35101
# Started subdivision (318): 24012
# 	station list: ['701LP0N']
# 	finished adding subdivision: 24012
# Started subdivision (319): 35046
# 	station list: ['6142286']
# 	finished adding subdivision: 35046
# Started subdivision (320): 24036
# 	station list: ['702FHL8']
# 	finished adding subdivision: 24036
# Started subdivision (321): 24035
# 	station list: ['7061288', '7065639', '7066686']
# 	finished adding subdivision: 24035
# Started subdivision (322): 35056
# 	station list: ['6158410']
# 	finished adding subdivision: 35056
# Started subdivision (323): 48019
# 	station list: ['3012202']
# 	finished adding subdivision: 48019
# Started subdivision (324): 35042
# 	station list: ['6010735', '6012199', '6014353', '6016525', '6032125', '6034076', '6037776']
# 	finished adding subdivision: 35042
# Started subdivision (325): 24055
# 	station list: ['7024745']
# 	finished adding subdivision: 24055
# Started subdivision (326): 48009
# 	station list: ['3031092']
# 	finished adding subdivision: 48009
# Started subdivision (327): 35086
# 	station list: ['6080192']
# 	finished adding subdivision: 35086
# Started subdivision (328): 35088
# 	station list: ['6106001']
# 	finished adding subdivision: 35088
# Started subdivision (329): 24025
# 	station list: ['7025442']
# 	finished adding subdivision: 24025
# Started subdivision (330): 35055
# 	station list: ['6158410']
# 	finished adding subdivision: 35055
# Started subdivision (331): 35023
# 	station list: ['6166415']
# 	finished adding subdivision: 35023
# Started subdivision (332): 24075
# 	station list: ['7025252']
# 	finished adding subdivision: 24075
# Started subdivision (333): 24024
# 	station list: ['7025251']
# 	finished adding subdivision: 24024
# Started subdivision (334): 47008
# 	station list: ['4013480', '40190LN']
# 	finished adding subdivision: 47008
# Started subdivision (335): 48021
# 	station list: ['3012216']
# 	finished adding subdivision: 48021
# Started subdivision (336): 24011
# 	station list: ['7027329']
# 	finished adding subdivision: 24011
# Started subdivision (337): 48022
# 	station list: ['3030830', '3031640', '3035198', '3036099', '3051R4R', '3056214', '305MGFF']
# 	finished adding subdivision: 48022
